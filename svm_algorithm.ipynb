# %% [markdown]
# <a href="https://colab.research.google.com/github/ariba8001-maker/Supervise-Machine-Learning-Model-/blob/main/svm_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Train Test Split
from sklearn.model_selection import train_test_split

# SVM Model
from sklearn.svm import SVC

# Evaluation
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    precision_score,
    recall_score,
    f1_score
)

# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV

# Cross Validation
from sklearn.model_selection import cross_val_score

# Pipeline
from sklearn.pipeline import Pipeline

# Save Model
import joblib

# %%
df = pd.read_csv('/content/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
# 768            0      123             77              0        1  36.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.replace("NaN", np.nan, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               769 non-null    int64
#  1   Glucose                   769 non-null    int64
#  2   BloodPressure             769 non-null    int64
#  3   SkinThickness             769 non-null    int64
#  4   Insulin                   769 non-null    int64
#  5   BMI                       769 non-null    float64
#  6   DiabetesPedigreeFunction  769 non-null    float64
#  7   Age                       769 non-null    int64
#  8   Outcome                   769 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.2 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   769.000000  769.000000     769.000000     769.000000  769.000000
# mean      3.840052  120.897269      69.115735      20.509753   79.697009
# std       3.370237   31.951886      19.345296      15.959020  115.203999
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   29.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                769.000000  769.000000  769.000000
# mean    31.998179                  0.471590   33.269181    0.349805
# std      7.880557                  0.331208   11.778737    0.477219
# ...

# %%
df.shape
# Out:
# (769, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df["Outcome"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.replace("NaN", np.nan, inplace=True)

# %%
df = df.dropna()

# %%
df['Outcome'].unique()
# Out:
# array([1, 0])

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    269
# Name: count, dtype: int64

# %%
sns.countplot(x=df["Outcome"])
plt.show()

# %%
df.drop('BMI', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               769 non-null    int64
#  1   Glucose                   769 non-null    int64
#  2   BloodPressure             769 non-null    int64
#  3   SkinThickness             769 non-null    int64
#  4   Insulin                   769 non-null    int64
#  5   DiabetesPedigreeFunction  769 non-null    float64
#  6   Age                       769 non-null    int64
#  7   Outcome                   769 non-null    int64
# dtypes: float64(1), int64(7)
# memory usage: 48.2 KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Your plotting code
df.hist(figsize=(10,10))
plt.show()

# %%
sns.pairplot(
    df[[
        'Pregnancies',
        'Glucose',
        'BloodPressure',
        'SkinThickness',
        'Insulin',
        'Age']],

)

plt.show()

# %%
plt.figure(figsize=(24,20))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
print(X.shape)
print(y.shape)
# Out:
# (769, 7)
# (769,)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
print(X_scaled.shape)
X_scaled = scaler.fit_transform(X)
# Out:
# (769, 7)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (615, 7)
# (154, 7)
# (615,)
# (154,)

# %% [markdown]
# Support Vector Machine

# %%
svm_model = SVC()

# %%
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale')

# %%
print(svm_model)
# Out:
# SVC()

# %%
svm_model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_model.predict(X_test)

# %%
svm_model.score(X_train, y_train)
# Out:
# 0.808130081300813

# %%
print(y_pred[:10])
# Out:
# [1 0 0 0 1 0 0 0 1 0]

# %%
comparison = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

comparison.head(10)
# Out:
#      Actual  Predicted
# 669       0          1
# 324       0          0
# 625       0          0
# 691       1          0
# 473       0          1
# 204       0          0
# 97        0          0
# 336       0          0
# 568       0          1
# 148       0          0

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7597402597402597

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[86 14]
#  [23 31]]

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
precision = precision_score(y_test, y_pred)
print("Precision:", precision)
# Out:
# Precision: 0.6888888888888889

# %%
recall = recall_score(y_test, y_pred)
print("Recall:", recall)
# Out:
# Recall: 0.5740740740740741

# %%
f1 = f1_score(y_test, y_pred)
print("F1 Score:", f1)
# Out:
# F1 Score: 0.6262626262626263

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82       100
#            1       0.69      0.57      0.63        54
#
#     accuracy                           0.76       154
#    macro avg       0.74      0.72      0.72       154
# weighted avg       0.75      0.76      0.75       154

# %% [markdown]
# HYPER PARAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf']
}

# %%
grid = GridSearchCV(
    SVC(),
    param_grid,
    refit=True,
    verbose=2,
    cv=5
)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# ...

# %%
print(grid.best_params_)
# Out:
# {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
best_model = grid.best_estimator_

# %%
y_pred_tuned = best_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Old Accuracy:", accuracy_score(y_test, y_pred))
print("Tuned Accuracy:", accuracy_score(y_test, y_pred_tuned))
# Out:
# Old Accuracy: 0.7597402597402597
# Tuned Accuracy: 0.7857142857142857

# %%
print("Old Classification Report:", classification_report(y_test, y_pred))
print("Tuned Classification Report:", classification_report(y_test, y_pred_tuned))
# Out:
# Old Classification Report:               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82       100
#            1       0.69      0.57      0.63        54
#
#     accuracy                           0.76       154
#    macro avg       0.74      0.72      0.72       154
# weighted avg       0.75      0.76      0.75       154
#
# Tuned Classification Report:               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       100
#            1       0.72      0.63      0.67        54
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.75      0.76       154
# weighted avg       0.78      0.79      0.78       154

# %%
cm = confusion_matrix(y_test, y_pred_tuned)
print(cm)
# Out:
# [[87 13]
#  [20 34]]

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# CROSS VALDATION

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    best_model,
    X_scaled,
    y,
    cv=5
)

# %%
print(scores)
# Out:
# [0.76623377 0.73376623 0.75974026 0.77922078 0.78431373]

# %%
print("Mean Accuracy:", scores.mean())
# Out:
# Mean Accuracy: 0.7646549528902471

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='rbf', C=10, gamma=0.01))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('svm', SVC(C=10, gamma=0.01))])

# %%
y_pred_pipeline = pipeline.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Pipeline Accuracy:", accuracy_score(y_test, y_pred_pipeline))
# Out:
# Pipeline Accuracy: 0.7857142857142857
